# %%
import os

# %%
path = os.path.join('../data', 'SpotifyAudioFeaturesApril2019.csv')

# %%
import pandas as pd

# %%
april2019 = pd.read_csv(path)

# %%
april2019.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# ...

# %%
april2019[april2019['track_id'] == '5ow0sNF1zSqp71Ix5jEXWU']
# Out:
#        artist_name                track_id                track_name  \
# 98687        Jubël  5ow0sNF1zSqp71Ix5jEXWU  Dancing in the Moonlight
# 125801       Jubel  5ow0sNF1zSqp71Ix5jEXWU  Dancing in the Moonlight
#
#         acousticness  danceability  duration_ms  energy  instrumentalness  \
# 98687           0.27         0.659       164010   0.617               0.0
# 125801          0.27         0.659       164010   0.617               0.0
#
#         key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 98687    11     0.187    -5.862     0       0.0649  119.858               4
# 125801   11     0.187    -5.862     0       0.0649  119.858               4
#
#         valence  popularity
# 98687     0.187          77
# 125801    0.187          77

# %%
artist = april2019[april2019['track_id'] == '6eEVqkT1ZWHHzg08rfj7Uc']
artist
# Out:
#        artist_name                track_id  \
# 98773          DDG  6eEVqkT1ZWHHzg08rfj7Uc
# 115490         DDG  6eEVqkT1ZWHHzg08rfj7Uc
# 121403         DDG  6eEVqkT1ZWHHzg08rfj7Uc
#
#                                                track_name  acousticness  \
# 98773                                           Run It Up        0.0925
# 115490  Run It Up (feat. YBN Nahmir, G Herbo & Blac Yo...        0.0925
# 121403                       Run It Up (feat. YBN Nahmir)        0.0925
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 98773          0.772       279014   0.702          0.000003    0     0.126
# 115490         0.772       279014   0.702          0.000003    0     0.126
# 121403         0.772       279014   0.702          0.000003    0     0.126
#
#         loudness  mode  speechiness   tempo  time_signature  valence  \
# 98773     -5.322     0        0.046  84.043               4    0.583
# ...

# %%
artist = april2019[april2019['track_id'] == '47mTZdlkxSxwh1eljtYFlo']
artist
# Out:
#             artist_name                track_id      track_name  acousticness  \
# 114846    Rebecca Sugar  47mTZdlkxSxwh1eljtYFlo  Time Adventure         0.965
# 116996       Tim Kiefer  47mTZdlkxSxwh1eljtYFlo  Time Adventure         0.965
# 130282  Various Artists  47mTZdlkxSxwh1eljtYFlo  Time Adventure         0.965
#
#         danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 114846         0.564       211204   0.383             0.923    0     0.117
# 116996         0.564       211204   0.383             0.923    0     0.117
# 130282         0.564       211204   0.383             0.923    0     0.117
#
#         loudness  mode  speechiness    tempo  time_signature  valence  \
# 114846   -17.366     1       0.0446  109.175               4    0.296
# 116996   -17.366     1       0.0446  109.175               4    0.296
# 130282   -17.366     1       0.0446  109.175               4    0.296
#
#         popularity
# 114846          49
# 116996          49
# ...

# %%
[april2019['track_id'].value_counts()]
# Out:
# [0UBafqn0HVWRceDnOv2SZu    4
#  1cvoD6PhuF31q08aaZYjki    3
#  6eEVqkT1ZWHHzg08rfj7Uc    3
#  4fbwTO3DJ2qryMddov9RbB    3
#  02mqJ3mpw8MLDmM2cqIVB9    3
#  47mTZdlkxSxwh1eljtYFlo    3
#  569BGSWQapYD8Niuy67Cal    3
#  1afyMOxQCyfxUOSrCkStsy    3
#  2iicKPnvOKfbJZJZtuQnjy    2
#  41Umx93nsocrD8ckKBSuno    2
#  6yOBmMQGYhgU5XQP0LSPGn    2
#  19SEn5eUuuixwxFPNtrq7D    2
#  3oCJJksC12uFxkt3RQ7rbV    2
#  0yPWj2trBQazAUasaLmqbU    2
#  6sZUGkgvbNfd4rabcQ8Tj7    2
#  69Sy7207dnixZ6w7RSV9Kb    2
#  0u2DOByL0CghKtcvSkQAiQ    2
#  3jnbd5B8VdKIXXySIBciuF    2
#  6XddLa3bdlJJQC6sImufdH    2
#  4mnetrP6ozVrc5lkM07WP3    2
#  0VmQ0QDmjPIvQBrwKqUrqX    2
#  467t3218y3yihFcyDGWjr0    2
#  10HNu5uFLPN77fwrHbqmAy    2
#  11TBBqxLKUQBlyGKJXfvOe    2
#  0mOp9tWdCRHfYwwVaO8ezw    2
#  3NsZEgicTC5JqUeuCsXQsC    2
#  2OvV4NjEBRE9v8Oo7QeUCq    2
#  4jAity3zdhAMTL3gy6cLGx    2
#  5ow0sNF1zSqp71Ix5jEXWU    2
#  28uC3JDFpW3Y18EPU5hGAF    2
#                           ..
#  64rJlCsS56nagD152DVFSc    1
# ...

# %%
print(artist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-7d1e62cae76f> in <module>
#       1 for i in artist:
# ----> 2     print(i.artist_name)
#
# AttributeError: 'str' object has no attribute 'artist_name'
