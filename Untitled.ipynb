# %%
import pandas as pd

# %%
df = pd.read_csv('SpotifyAudioFeaturesApril2019.csv')

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# ...

# %%
df[df.duplicated(subset='track_id') == True].sort_values(by='track_id')
# Out:
#                   artist_name                track_id  \
# 119258           Clean Bandit  02mqJ3mpw8MLDmM2cqIVB9
# 121309           Clean Bandit  02mqJ3mpw8MLDmM2cqIVB9
# 126535        Hillsong UNITED  03UNuZgtHViMboufVtawCa
# 124946             Young Thug  04yv0dtqVm9u745efIuxbZ
# 129441         The Piano Guys  06XspRiZpjqVdXVdJNVxzB
# 118726     Lenny code fiction  07X9vVzKciQRl5wkfM1Jre
# 125230                  gnash  08AVKNJ46gnUvr5wVCTrG5
# 127095             KAYTRANADA  08M1S4uwtmPM0jIO1qNyhx
# 123604             Ed Sheeran  0AOvD8LrdeDVDaLzSB7YsM
# 128300          Natalie Grant  0AiQLGevpr9XOc9kIRjyuB
# 118133                   CHIC  0BOoghyiRci1ANsQba1FKS
# 113013                    KUN  0C9XP9CGAqh9YoCcgSXh1T
# 117369             Andy Mineo  0CP7PZHresH8TiGq62MSuQ
# 128847             ✦Pink Cig✦  0IkLMN8d1HQcpbvskhz6f3
# 97601                  Boogie  0LGU5IvoXwGfRpbgr09UsJ
# 118147         Oliver Heldens  0M0FvSNRZmDz0Z769rewlI
# ...

# %%
df['track_id_len'] = df['track_id'].apply(len)

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# ...

# %%
df['track_id_len'].value_counts()
# Out:
# 22    130663
# Name: track_id_len, dtype: int64

# %%
df['track_name_len'] = df['track_name'].apply(len)

# %%
df['track_name_len'].max()
# Out:
# 215

# %%
df['artist_name_len'] = df['artist_name'].apply(len)

# %%
df['artist_name_len'].max()
# Out:
# 75

# %%
df['popularity'].value_counts()
# Out:
# 0      18889
# 1       3217
# 19      2537
# 22      2525
# 2       2517
# 23      2436
# 20      2434
# 18      2412
# 17      2377
# 21      2360
# 16      2267
# 15      2241
# 24      2202
# 30      2187
# 13      2138
# 28      2135
# 25      2128
# 31      2110
# 14      2110
# 12      2092
# 9       2091
# 29      2087
# 11      2056
# 10      2044
# 3       2033
# 27      2019
# 32      1970
# 8       1916
# 26      1911
# 6       1900
#        ...
# 70       262
# 71       234
# 72       211
# 73       183
# 74       138
# 75       135
# 76       118
# 77       105
# 78        88
# 79        82
# 80        70
# 81        56
# 82        44
# 83        44
# 85        42
# 84        41
# 88        30
# 86        29
# 87        25
# 91        17
# 89        14
# 94        11
# 90         9
# 92         7
# 96         7
# 95         6
# 93         6
# 98         4
# 97         1
# 100        1
# Name: popularity, Length: 100, dtype: int64

# %%
df[df['popularity']==100]
# Out:
#         artist_name                track_id track_name  acousticness  \
# 99393  Daddy Yankee  5w9c2J52mkdntKOmRLeM2m  Con Calma          0.11
#
#        danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 99393         0.737       193227    0.86          0.000002    8    0.0574
#
#        loudness  mode  speechiness   tempo  time_signature  valence  \
# 99393    -2.652     0       0.0593  93.989               4    0.656
#
#        popularity  track_id_len  track_name_len  artist_name_len
# 99393         100            22               9               12

# %%
# !pip install spotipy
# Out:
# ...
#   Stored in directory: C:\Users\Me\AppData\Local\pip\Cache\wheels\76\28\19\a86ca9bb0e32dbd4a4f580870250f5aeef852870578e0427e6
# Successfully built spotipy
# ...

# %%
client_id='a1e73a8b567a434e9f40ebccfe2085c0'
client_secret='4010b21ddc914618894db16f31cfdfd3'

# %%
import spotipy
import spotipy.oauth2 as oauth2
spotify = spotipy.Spotify()
credentials = oauth2.SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)
name = 'The Beatles'
results = spotify.search(q='artist:' + name, type='artist')
print(results)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3AThe+Beatles&type=artist&offset=0&limit=10', 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'}, 'followers': {'href': None, 'total': 13795942}, 'genres': ['british invasion', 'merseybeat', 'psychedelic rock', 'rock'], 'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2', 'id': '3WrFJ7ztbogyGnTHbHJFl2', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/6b2a709752ef9c7aaf0d270344157f6cd2e0f1a7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/1047bf172446f2a815a99ab0a0395099d621be51', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/0561b59a91a5e904ad2d192747715688d5f05012', 'width': 160}], 'name': 'The Beatles', 'popularity': 89, 'type': 'artist', 'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1UarLtyjvxGiRTsfFXxtnA'}, 'followers': {'href': None, 'total
# ...

# %%
track_id = '4uLU6hMCjMI75M1A2tKUQC'
results = spotify.track(track_id)
print(results)
# Out:
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gxyHStUsqpMadRV0Di1Qt'}, 'href': 'https://api.spotify.com/v1/artists/0gxyHStUsqpMadRV0Di1Qt', 'id': '0gxyHStUsqpMadRV0Di1Qt', 'name': 'Rick Astley', 'type': 'artist', 'uri': 'spotify:artist:0gxyHStUsqpMadRV0Di1Qt'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6N9PS4QXF1D0OWPk0Sxtb4'}, 'href': 'https://api.spotify.com/v1/albums/6N9PS4QXF1D0OWPk0Sxtb4', 'id': '6N9PS4QXF1D0OWPk0S
# ...
